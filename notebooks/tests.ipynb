# %%
import sys
sys.path.insert(0, '../')

# %%
from download_checkpoints import download_checkpoint_as_file_object

download_checkpoint_as_file_object('music_project_bucket', 'model_best.ckpt')
# Out:
# Downloaded model_best.ckpt.
# Downloaded pretrain_model.ckpt.
# None None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /root/code/HugoA45/music_project/music_project/notebooks/tests.ipynb Cell 2 line 3
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/root/code/HugoA45/music_project/music_project/notebooks/tests.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from download_checkpoints import download_checkpoint_as_file_object
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/root/code/HugoA45/music_project/music_project/notebooks/tests.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> download_checkpoint_as_file_object('music_project_bucket', 'model_best.ckpt')
#
# File ~/code/HugoA45/music_project/music_project/notebooks/../download_checkpoints.py:21, in download_checkpoint_as_file_object(bucket_name, checkpoint_file)
#      18 bucket = client.bucket(bucket_name)
# ...
